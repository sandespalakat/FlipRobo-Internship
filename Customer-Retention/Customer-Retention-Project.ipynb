# %% [markdown]
# ## Customer-Retention-Project

# %% [markdown]
# PROBLEM STATEMENT
#
# E-retail factors for customer activation and retention: A case study from Indian e-commerce customers
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.
# Be careful: There are two sheets (one is detailed) and second is encoded in the excel file. You may use any of them by extracting in separate excel sheet. The number of column(s) is more than 47. Read the column header carefully.
# Note : Data Scientists have to apply their analytical skills to give findings and conclusions in detailed data analysis written in jupyter notebook . Only data analysis is required.
#
# <img src="https://imgur.com/3qhVxbB.png">

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_excel("Customer_retention_dataset/train.xlsx", sheet_name=0)
pd.set_option("display.max_columns", None)

# %%
data
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
data2 = pd.read_excel("Customer_retention_dataset/train.xlsx", sheet_name=1)
# pd.set_option("display.max_columns", None)

# %%
data2
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
data.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
data.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
sns.countplot(data.iloc[:,0])

# %% [raw]
# Male respondents are lesser than female respondents

# %%
#getting the age information by multiplying with 10(in the data age is given as 2 for 21-30)
data.iloc[:,1] = data.iloc[:,1] * 10

# %%
sns.countplot(data.iloc[:,1])

# %% [raw]
# Most of the respondents belongs to the age group 30-40

# %%
sns.countplot(data.iloc[:,1], hue=data.iloc[:,0])

# %% [raw]
# In all age slabs, female respondents are higher

# %%
data.iloc[:,2].unique()
# Out:
# array(['Delhi', 'Greater Noida', 'Karnal ', 'Bangalore ', 'Noida',
#        'Solan', 'Moradabad', 'Gurgaon ', 'Merrut', 'Ghaziabad',
#        'Bulandshahr'], dtype=object)

# %% [raw]
# The survey has taken place in the following states/cities only
# Delhi
# UP
# Haryana
# Himachal Pradesh
# Karnataka(Banglore)

# %%
sns.countplot(data.iloc[:,4])

# %% [raw]
# The largest number of respondents have more experienced

# %%
sns.countplot(data.iloc[:,5])

# %%
sns.countplot(data.iloc[:,5], hue=data.iloc[:,0])

# %% [raw]
# Female users purchase more than men

# %%
sns.countplot(data.iloc[:,6])

# %%
sns.countplot(data.iloc[:,6], hue=data.iloc[:,0])

# %% [raw]
# Most of the users mobile internet to purchase online

# %%
sns.countplot(data.iloc[:,7])

# %% [raw]
# since most of the users use mobile internet to purchase, smartphone will be their device

# %%
sns.countplot(data.iloc[:,8], hue=data.iloc[:,0])

# %%
sns.countplot(data.iloc[:,9], hue=data.iloc[:,0])

# %% [raw]
# More people using windows OS for purchasing online

# %%
sns.countplot(data.iloc[:,9], hue=data.iloc[:,8])

# %%
sns.countplot(data.iloc[:,7], hue=data.iloc[:,9])

# %% [raw]
# There are no repondents from Mac(Desktop) users
# Most of the respondents from smartphones are Android users
# Laptop users are more than desktop users
# Respondents who use apple laptops are very less

# %%
sns.countplot(data.iloc[:,10])

# %%
sns.countplot(data.iloc[:,10], hue=data.iloc[:,9])

# %% [raw]
# In Google Chrome users, most of them are using windows OS
# There are very few are using Mozilla Firefox and Opera browser
# Around half of the IOS users use chrome for online shopping

# %%
sns.countplot(data.iloc[:,11])

# %% [raw]
# Most of the users reached the shopping website by the search engine for the first time
# Only less than 20% of the customers visit the shopping website through content marketing and advertisements

# %%
sns.countplot(data.iloc[:,9], hue=data.iloc[:,11])

# %% [raw]
# No customers reached through content marketing from windows OS
# NO customers reached through adverts from IOS

# %%
sns.countplot(data.iloc[:,12])

# %% [raw]
# After the first use people who use application direcly increses
# After the first use, people browse url directly also increases

# %%
sns.barplot(data.iloc[:,11], data2.iloc[:,8])

# %% [raw]
# Customers which earned through content marketing was through lesser screen size devices

# %%
sns.countplot(data.iloc[:,13])

# %% [raw]
# Most of the people spend more than 15 minutes to make a decision to purchase

# %%
sns.countplot(data.iloc[:,13], hue=data2.iloc[:,1])

# %% [raw]
# People who have age between 20 and 30 take more time to make purchase decision
# People between 30 and 40 make purchase decision very quickly

# %%
sns.countplot(data.iloc[:,14])

# %% [raw]
# Most of the people use card transactions for purchase

# %%
sns.countplot(data.iloc[:,14], hue=data2.iloc[:,1])

# %%
sns.countplot(data2.iloc[:,1], hue=data.iloc[:,14])

# %% [raw]
# People who aged between 20 and 30 mainly uses card(credit/debit) for purchase
# People aged above 50 not at all using e wallets for purchasing

# %%
sns.countplot(data.iloc[:,15])

# %%
chart = sns.countplot(data.iloc[:,16])
chart.tick_params(labelsize=12)
chart.set_xticklabels(chart.get_xticklabels(), rotation=80)
# Out:
# [Text(0, 0, 'Lack of trust'),
#  Text(0, 0, 'Promo code not applicable'),
#  Text(0, 0, 'Better alternative offer'),
#  Text(0, 0, 'Change in price'),
#  Text(0, 0, 'No preferred mode of payment')]

# %% [raw]
# Most of the people abandon cart because of the better alternative offer

# %%
#get the ages of people who abandons cart for alternative offers
ages = data2[data2.iloc[:,16] == 2].iloc[:,1]

# %%
sns.countplot(ages)

# %% [raw]
# People ages between 20 and forty are looking for alternative offers aggressively

# %%
chart = sns.countplot(data.iloc[:,17])
chart.tick_params(labelsize=12)
chart.set_xticklabels(chart.get_xticklabels(), rotation=80)
# Out:
# [Text(0, 0, 'Agree (4)'),
#  Text(0, 0, 'Strongly agree (5)'),
#  Text(0, 0, 'Strongly disagree (1)'),
#  Text(0, 0, 'Indifferent (3)')]

# %% [raw]
# Most of the users agree that their online store website is easily readable

# %%
sns.countplot(data.iloc[:,18])

# %% [raw]
# most of the people agree that product comparison is good on their online shopping website

# %%
sns.countplot(data.iloc[:,19])

# %%
sns.countplot(data.iloc[:,20])

# %% [raw]
# Most of the people agree that relevant info is shared clearly on their shopping website

# %%
sns.countplot(data2.iloc[:,1], hue=data.iloc[:,20])

# %% [raw]
# People aged between 20 and 40 are satisfied with the relevent information about the product on the shopping website

# %%
sns.countplot(data.iloc[:,21])

# %% [raw]
# Most of the websites have easy navigation system

# %%
# 17-23
# here we are going to findthe average overall performance of the website (design, ease of use etc)
overall = (data2.iloc[:,17] + data2.iloc[:,18] + data2.iloc[:,19] + data2.iloc[:,20] +\
        data2.iloc[:,21] + data2.iloc[:,22] + data2.iloc[:,23])/7

# %%
chart = sns.countplot(overall)
chart.tick_params(labelsize=12)
chart.set_xticklabels(chart.get_xticklabels(), rotation=80)
# Out:
# [Text(0, 0, '1.4285714285714286'),
#  Text(0, 0, '3.0'),
#  Text(0, 0, '3.5714285714285716'),
#  Text(0, 0, '4.0'),
#  Text(0, 0, '4.142857142857143'),
#  Text(0, 0, '4.285714285714286'),
#  Text(0, 0, '4.428571428571429'),
#  Text(0, 0, '4.571428571428571'),
#  Text(0, 0, '4.714285714285714'),
#  Text(0, 0, '5.0')]

# %% [raw]
# Respondents rated as overall good as website performance like design, loading, info etc

# %%
sns.countplot(data.iloc[:,24])

# %%
sns.countplot(data.iloc[:,24], hue=data2.iloc[:,1])

# %% [raw]
# Most of the customers are satisfied with the payment options given on the shopping website

# %%
sns.countplot(data.iloc[:,25])

# %%
sns.countplot(data.iloc[:,25], hue=data2.iloc[:,1])

# %% [raw]
# Most of the peple trust the transaction system
# People in 30s trust the transaction fullfilment most people in 40s have less trust

# %%
sns.countplot(data.iloc[:,26])

# %% [raw]
# Majority of people agree that shopping website has empathy

# %%
sns.countplot(data.iloc[:,27])

# %%
sns.countplot(data.iloc[:,27], hue=data2.iloc[:,1])

# %% [raw]
# Most of the users are thinking the website gives good privacy to them

# %%
sns.countplot(data.iloc[:,28])

# %% [raw]
# above 50% people agree that their shopping website has good communication

# %%
sns.countplot(data.iloc[:,29])

# %% [raw]
# MOst of the people think that they are saving when they shop online
# Very few people think that there is no benefit in purchasing online

# %%
sns.countplot(data.iloc[:,31])

# %% [raw]
# Online shopping is convenient for most of the people

# %%
sns.countplot(data.iloc[:,32])

# %% [raw]
# It is obvious that return policy is matter for most of the people

# %%
sns.countplot(data.iloc[:,33])

# %%
sns.countplot(data.iloc[:,33], hue=data.iloc[:,0])

# %% [raw]
# Female users consider loyality point is important than males

# %%
sns.countplot(data.iloc[:,33], hue=data2.iloc[:,1])

# %%
sns.countplot(data.iloc[:,37])

# %% [raw]
# Trust and satisfaction are correlated

# %%
sns.countplot(data.iloc[:,46])

# %%
chart = sns.countplot(data.iloc[:,47])
chart.tick_params(labelsize=12)
chart.set_xticklabels(chart.get_xticklabels(), rotation=80)
# Out:
# [Text(0, 0, 'Amazon.in, Paytm.com'),
#  Text(0, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(0, 0, 'Amazon.in, Paytm.com, Myntra.com'),
#  Text(0, 0, 'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com'),
#  Text(0, 0, 'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com'),
#  Text(0, 0, 'Amazon.in, Flipkart.com'),
#  Text(0, 0, 'Amazon.in, Flipkart.com, Snapdeal.com'),
#  Text(0, 0, 'Amazon.in'),
#  Text(0, 0, 'Amazon.in, Flipkart.com, Paytm.com')]

# %% [raw]
# All peopel used Amazon.in for online purchase
# Most of the people used Flipkart for online purchase

# %%
#Create a new dataframe from colummn 47 according to user review for each shopping website

# %%
shopped = pd.DataFrame()
shopped["amazon_shopped"] = data.iloc[:,47].apply((lambda x: 1 if "amazon" in x.lower() else 0))
shopped["paytm_shopped"] = data.iloc[:,47].apply((lambda x: 1 if "paytm" in x.lower() else 0))
shopped["flipkart_shopped"] = data.iloc[:,47].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
shopped["myntra_shopped"] = data.iloc[:,47].apply((lambda x: 1 if "myntra" in x.lower() else 0))
shopped["snapdeal_shopped"] = data.iloc[:,47].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

# %%
shopped.describe()
# Out:
#        amazon_shopped  paytm_shopped  flipkart_shopped  myntra_shopped  \
# count           269.0     269.000000        269.000000      269.000000
# mean              1.0       0.557621          0.821561        0.542751
# std               0.0       0.497595          0.383595        0.499098
# min               1.0       0.000000          0.000000        0.000000
# 25%               1.0       0.000000          1.000000        0.000000
# 50%               1.0       1.000000          1.000000        1.000000
# 75%               1.0       1.000000          1.000000        1.000000
# max               1.0       1.000000          1.000000        1.000000
#
#        snapdeal_shopped
# count        269.000000
# mean           0.676580
# std            0.468653
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            1.000000
# max            1.000000

# %% [raw]
# Myntra has lesser number of customers as per the response

# %%
easy = pd.DataFrame()
easy["amazon_easy_use"] = data.iloc[:,48].apply((lambda x: 1 if "amazon" in x.lower() else 0))
easy["paytm_easy_use"] = data.iloc[:,48].apply((lambda x: 1 if "paytm" in x.lower() else 0))
easy["flipkart_easy_use"] = data.iloc[:,48].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
easy["myntra_easy_use"] = data.iloc[:,48].apply((lambda x: 1 if "myntra" in x.lower() else 0))
easy["snapdeal_easy_use"] = data.iloc[:,48].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

# %%
easy.describe()
# Out:
#        amazon_easy_use  paytm_easy_use  flipkart_easy_use  myntra_easy_use  \
# count       269.000000      269.000000         269.000000       269.000000
# mean          0.925651        0.464684           0.747212         0.546468
# std           0.262828        0.499681           0.435421         0.498764
# min           0.000000        0.000000           0.000000         0.000000
# 25%           1.000000        0.000000           0.000000         0.000000
# 50%           1.000000        0.000000           1.000000         1.000000
# 75%           1.000000        1.000000           1.000000         1.000000
# max           1.000000        1.000000           1.000000         1.000000
#
#        snapdeal_easy_use
# count         269.000000
# mean            0.483271
# std             0.500652
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             1.000000
# max             1.000000

# %% [raw]
# Flipkart and Amazon are the most easy usable platforms
# Paytm is the lease easy usable

# %%
appeal = pd.DataFrame()
appeal["amazon_vis_appeal"] = data.iloc[:,49].apply((lambda x: 1 if "amazon" in x.lower() else 0))
appeal["paytm_vis_appeal"] = data.iloc[:,49].apply((lambda x: 1 if "paytm" in x.lower() else 0))
appeal["flipkart_vis_appeal"] = data.iloc[:,49].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
appeal["myntra_vis_appeal"] = data.iloc[:,49].apply((lambda x: 1 if "myntra" in x.lower() else 0))
appeal["snapdeal_vis_appeal"] = data.iloc[:,49].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

# %%
appeal.describe()
# Out:
#        amazon_vis_appeal  paytm_vis_appeal  flipkart_vis_appeal  \
# count         269.000000        269.000000           269.000000
# mean            0.843866          0.249071             0.650558
# std             0.363659          0.433281             0.477683
# min             0.000000          0.000000             0.000000
# 25%             1.000000          0.000000             0.000000
# 50%             1.000000          0.000000             1.000000
# 75%             1.000000          0.000000             1.000000
# max             1.000000          1.000000             1.000000
#
#        myntra_vis_appeal  snapdeal_vis_appeal
# count         269.000000           269.000000
# mean            0.427509             0.226766
# std             0.495639             0.419520
# min             0.000000             0.000000
# 25%             0.000000             0.000000
# 50%             0.000000             0.000000
# 75%             1.000000             0.000000
# ...

# %% [raw]
# Amazon is the most visually appealing website
# Snapdeal is the least visually appealing website

# %%
veriety = pd.DataFrame()
veriety["amazon_veriety"] = data.iloc[:,50].apply((lambda x: 1 if "amazon" in x.lower() else 0))
veriety["paytm_veriety"] = data.iloc[:,50].apply((lambda x: 1 if "paytm" in x.lower() else 0))
veriety["flipkart_veriety"] = data.iloc[:,50].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
veriety["myntra_veriety"] = data.iloc[:,50].apply((lambda x: 1 if "myntra" in x.lower() else 0))
veriety["snapdeal_veriety"] = data.iloc[:,50].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

# %%
veriety.describe()
# Out:
#        amazon_veriety  paytm_veriety  flipkart_veriety  myntra_veriety  \
# count      269.000000     269.000000        269.000000      269.000000
# mean         0.817844       0.074349          0.684015        0.237918
# std          0.386693       0.262828          0.465774        0.426602
# min          0.000000       0.000000          0.000000        0.000000
# 25%          1.000000       0.000000          0.000000        0.000000
# 50%          1.000000       0.000000          1.000000        0.000000
# 75%          1.000000       0.000000          1.000000        0.000000
# max          1.000000       1.000000          1.000000        1.000000
#
#        snapdeal_veriety
# count        269.000000
# mean           0.052045
# std            0.222531
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %% [raw]
# Amazon and Flipkart are leading in veriety of products
# Snapdeal and Paytm have less veriety products

# %%
description = pd.DataFrame()
description["amazon_desc"] = data.iloc[:,51].apply((lambda x: 1 if "amazon" in x.lower() else 0))
description["paytm_desc"] = data.iloc[:,51].apply((lambda x: 1 if "paytm" in x.lower() else 0))
description["flipkart_desc"] = data.iloc[:,51].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
description["myntra_desc"] = data.iloc[:,51].apply((lambda x: 1 if "myntra" in x.lower() else 0))
description["snapdeal_desc"] = data.iloc[:,51].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

# %%
description.describe()
# Out:
#        amazon_desc  paytm_desc  flipkart_desc  myntra_desc  snapdeal_desc
# count   269.000000  269.000000      269.00000   269.000000     269.000000
# mean      0.884758    0.219331        0.72119     0.237918       0.219331
# std       0.319909    0.414565        0.44925     0.426602       0.414565
# min       0.000000    0.000000        0.00000     0.000000       0.000000
# 25%       1.000000    0.000000        0.00000     0.000000       0.000000
# 50%       1.000000    0.000000        1.00000     0.000000       0.000000
# 75%       1.000000    0.000000        1.00000     0.000000       0.000000
# max       1.000000    1.000000        1.00000     1.000000       1.000000

# %% [raw]
# Amazon gives high in description
# Lowest for snapdeal and Paytm

# %%
#Loading speed
ld_speed = pd.DataFrame()
ld_speed["amazon_load_speed"] = data.iloc[:,52].apply((lambda x: 1 if "amazon" in x.lower() else 0))
ld_speed["paytm_load_speed"] = data.iloc[:,52].apply((lambda x: 1 if "paytm" in x.lower() else 0))
ld_speed["flipkart_load_speed"] = data.iloc[:,52].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
ld_speed["myntra_load_speed"] = data.iloc[:,52].apply((lambda x: 1 if "myntra" in x.lower() else 0))
ld_speed["snapdeal_load_speed"] = data.iloc[:,52].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

# %%
ld_speed.describe()
# Out:
#        amazon_load_speed  paytm_load_speed  flipkart_load_speed  \
# count         269.000000        269.000000            269.00000
# mean            0.925651          0.368030              0.60223
# std             0.262828          0.483168              0.49035
# min             0.000000          0.000000              0.00000
# 25%             1.000000          0.000000              0.00000
# 50%             1.000000          0.000000              1.00000
# 75%             1.000000          1.000000              1.00000
# max             1.000000          1.000000              1.00000
#
#        myntra_load_speed  snapdeal_load_speed
# count         269.000000           269.000000
# mean            0.275093             0.301115
# std             0.447393             0.459598
# min             0.000000             0.000000
# 25%             0.000000             0.000000
# 50%             0.000000             0.000000
# 75%             1.000000             1.000000
# ...

# %% [raw]
# Amazon has the highest loadign speed
# Myntra has least laoding speed

# %%
modi_data = pd.DataFrame()
modi_data["amazon_reliability"] = data.iloc[:,53].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_reliability"] = data.iloc[:,53].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_reliability"] = data.iloc[:,53].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_reliability"] = data.iloc[:,53].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_reliability"] = data.iloc[:,53].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_qk_purchase"] = data.iloc[:,54].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_qk_purchase"] = data.iloc[:,54].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_qk_purchase"] = data.iloc[:,54].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_qk_purchase"] = data.iloc[:,54].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_qk_purchase"] = data.iloc[:,54].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_pay_opt"] = data.iloc[:,55].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_pay_opt"] = data.iloc[:,55].apply((lambda x: 1 if "patym" in x.lower() else 0))
modi_data["flipkart_pay_opt"] = data.iloc[:,55].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_pay_opt"] = data.iloc[:,55].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_pay_opt"] = data.iloc[:,55].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_speed_del"] = data.iloc[:,56].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_speed_del"] = data.iloc[:,56].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_speed_del"] = data.iloc[:,56].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_speed_del"] = data.iloc[:,56].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_speed_del"] = data.iloc[:,56].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_privacy"] = data.iloc[:,57].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_privacy"] = data.iloc[:,57].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_privacy"] = data.iloc[:,57].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_privacy"] = data.iloc[:,57].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_privacy"] = data.iloc[:,57].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_fin_security"] = data.iloc[:,58].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_fin_security"] = data.iloc[:,58].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_fin_security"] = data.iloc[:,58].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_fin_security"] = data.iloc[:,58].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_fin_security"] = data.iloc[:,58].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_trust"] = data.iloc[:,59].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_trust"] = data.iloc[:,59].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_trust"] = data.iloc[:,59].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_trust"] = data.iloc[:,59].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_trust"] = data.iloc[:,59].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_assist"] = data.iloc[:,60].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_assist"] = data.iloc[:,60].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_assist"] = data.iloc[:,60].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_assist"] = data.iloc[:,60].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_assist"] = data.iloc[:,60].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_long_log"] = data.iloc[:,61].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_long_log"] = data.iloc[:,61].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_long_log"] = data.iloc[:,61].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_long_log"] = data.iloc[:,61].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_long_log"] = data.iloc[:,61].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_long_promo"] = data.iloc[:,62].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_long_promo"] = data.iloc[:,62].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_long_promo"] = data.iloc[:,62].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_long_promo"] = data.iloc[:,62].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_long_promo"] = data.iloc[:,62].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_late_price"] = data.iloc[:,63].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_late_price"] = data.iloc[:,63].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_late_price"] = data.iloc[:,63].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_late_price"] = data.iloc[:,63].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_late_price"] = data.iloc[:,63].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_long_load"] = data.iloc[:,64].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_long_load"] = data.iloc[:,64].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_long_load"] = data.iloc[:,64].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_long_load"] = data.iloc[:,64].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_long_load"] = data.iloc[:,64].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_lim_pay_opt"] = data.iloc[:,65].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_lim_pay_opt"] = data.iloc[:,65].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_lim_pay_opt"] = data.iloc[:,65].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_lim_pay_opt"] = data.iloc[:,65].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_lim_pay_opt"] = data.iloc[:,65].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_long_del_per"] = data.iloc[:,66].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_long_del_per"] = data.iloc[:,66].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_long_del_per"] = data.iloc[:,66].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_long_del_per"] = data.iloc[:,66].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_long_del_per"] = data.iloc[:,66].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_change_site"] = data.iloc[:,67].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_change_site"] = data.iloc[:,67].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_change_site"] = data.iloc[:,67].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_change_site"] = data.iloc[:,67].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_change_site"] = data.iloc[:,67].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_freq_dis"] = data.iloc[:,68].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_freq_dis"] = data.iloc[:,68].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_freq_dis"] = data.iloc[:,68].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_freq_dis"] = data.iloc[:,68].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_freq_dis"] = data.iloc[:,68].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_efficient"] = data.iloc[:,69].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_efficient"] = data.iloc[:,69].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_efficient"] = data.iloc[:,69].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_efficient"] = data.iloc[:,69].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_efficient"] = data.iloc[:,69].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

modi_data["amazon_reccommend"] = data.iloc[:,70].apply((lambda x: 1 if "amazon" in x.lower() else 0))
modi_data["paytm_reccommend"] = data.iloc[:,70].apply((lambda x: 1 if "paytm" in x.lower() else 0))
modi_data["flipkart_reccommend"] = data.iloc[:,70].apply((lambda x: 1 if "flipkart" in x.lower() else 0))
modi_data["myntra_reccommend"] = data.iloc[:,70].apply((lambda x: 1 if "myntra" in x.lower() else 0))
modi_data["snapdeal_reccommend"] = data.iloc[:,70].apply((lambda x: 1 if "snapdeal" in x.lower() else 0))

# %%
modi_data
# Out:
#      amazon_reliability  paytm_reliability  flipkart_reliability  \
# 0                     0                  1                     0
# 1                     0                  0                     0
# 2                     1                  1                     0
# 3                     1                  1                     1
# 4                     1                  1                     0
# ..                  ...                ...                   ...
# 264                   1                  0                     0
# 265                   0                  0                     1
# 266                   1                  0                     0
# 267                   1                  0                     1
# 268                   1                  0                     0
#
#      myntra_reliability  snapdeal_reliability  amazon_qk_purchase  \
# 0                     0                     0                   0
# ...

# %%
#reliability
modi_data.iloc[:,0:5].describe()
# Out:
#        amazon_reliability  paytm_reliability  flipkart_reliability  \
# count          269.000000         269.000000            269.000000
# mean             0.843866           0.356877              0.542751
# std              0.363659           0.479971              0.499098
# min              0.000000           0.000000              0.000000
# 25%              1.000000           0.000000              0.000000
# 50%              1.000000           0.000000              1.000000
# 75%              1.000000           1.000000              1.000000
# max              1.000000           1.000000              1.000000
#
#        myntra_reliability  snapdeal_reliability
# count          269.000000            269.000000
# mean             0.237918              0.167286
# std              0.426602              0.373927
# min              0.000000              0.000000
# 25%              0.000000              0.000000
# 50%              0.000000              0.000000
# ...

# %% [raw]
# amazon has highest reliability
# Snapdeal has least reliability

# %%
#quick purchase
modi_data.iloc[:,5:10].describe()
# Out:
#        amazon_qk_purchase  paytm_qk_purchase  flipkart_qk_purchase  \
# count          269.000000          269.00000            269.000000
# mean             0.799257            0.39777              0.587361
# std              0.401303            0.49035              0.493227
# min              0.000000            0.00000              0.000000
# 25%              1.000000            0.00000              0.000000
# 50%              1.000000            0.00000              1.000000
# 75%              1.000000            1.00000              1.000000
# max              1.000000            1.00000              1.000000
#
#        myntra_qk_purchase  snapdeal_qk_purchase
# count          269.000000            269.000000
# mean             0.293680              0.107807
# std              0.456296              0.310714
# min              0.000000              0.000000
# 25%              0.000000              0.000000
# 50%              0.000000              0.000000
# ...

# %% [raw]
# Customers who use Amazon have opinion that they can purchase quickly from the website

# %%
#payment options
modi_data.iloc[:,10:15].describe()
# Out:
#        amazon_pay_opt  paytm_pay_opt  flipkart_pay_opt  myntra_pay_opt  \
# count      269.000000     269.000000        269.000000      269.000000
# mean         0.799257       0.304833          0.754647        0.490706
# std          0.401303       0.461195          0.431098        0.500845
# min          0.000000       0.000000          0.000000        0.000000
# 25%          1.000000       0.000000          1.000000        0.000000
# 50%          1.000000       0.000000          1.000000        0.000000
# 75%          1.000000       1.000000          1.000000        1.000000
# max          1.000000       1.000000          1.000000        1.000000
#
#        snapdeal_pay_opt
# count        269.000000
# mean           0.334572
# std            0.472720
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            1.000000
# max            1.000000

# %% [raw]
# For different payment options, Amazon and Flipkart are almost same
# Paytm has least no. of payment method

# %%
# delivery speed
modi_data.iloc[:,15:20].describe()
# Out:
#        amazon_speed_del  paytm_speed_del  flipkart_speed_del  \
# count        269.000000            269.0           269.00000
# mean           0.892193              0.0             0.60223
# std            0.310714              0.0             0.49035
# min            0.000000              0.0             0.00000
# 25%            1.000000              0.0             0.00000
# 50%            1.000000              0.0             1.00000
# 75%            1.000000              0.0             1.00000
# max            1.000000              0.0             1.00000
#
#        myntra_speed_del  snapdeal_speed_del
# count        269.000000          269.000000
# mean           0.107807            0.185874
# std            0.310714            0.389730
# min            0.000000            0.000000
# 25%            0.000000            0.000000
# 50%            0.000000            0.000000
# 75%            0.000000            0.000000
# max            1.000000            1.000000

# %% [raw]
# Amazon has the greatest delivery speed
# No respondents choose Paytm

# %%
#privacy
modi_data.iloc[:,20:25].describe()
# Out:
#        amazon_privacy  paytm_privacy  flipkart_privacy  myntra_privacy  \
# count      269.000000     269.000000        269.000000      269.000000
# mean         0.821561       0.252788          0.557621        0.289963
# std          0.383595       0.435421          0.497595        0.454591
# min          0.000000       0.000000          0.000000        0.000000
# 25%          1.000000       0.000000          0.000000        0.000000
# 50%          1.000000       0.000000          1.000000        0.000000
# 75%          1.000000       1.000000          1.000000        1.000000
# max          1.000000       1.000000          1.000000        1.000000
#
#        snapdeal_privacy
# count        269.000000
# mean           0.167286
# std            0.373927
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %% [raw]
# Amazon offers good privacy to the customers
# Aound half of the respondents who are purchasing from Flipkart do not think they give privacy

# %%
#security in terms of financal transactions
modi_data.iloc[:,25:30].describe()
# Out:
#        amazon_fin_security  paytm_fin_security  flipkart_fin_security  \
# count           269.000000          269.000000             269.000000
# mean              0.765799            0.327138               0.553903
# std               0.424288            0.470042               0.498012
# min               0.000000            0.000000               0.000000
# 25%               1.000000            0.000000               0.000000
# 50%               1.000000            0.000000               1.000000
# 75%               1.000000            1.000000               1.000000
# max               1.000000            1.000000               1.000000
#
#        myntra_fin_security  snapdeal_fin_security
# count            269.00000             269.000000
# mean               0.33829               0.371747
# std                0.47401               0.484172
# min                0.00000               0.000000
# 25%                0.00000               0.000000
# ...

# %%
#trustworthiness
modi_data.iloc[:,30:35].describe()
# Out:
#        amazon_trust  paytm_trust  flipkart_trust  myntra_trust  snapdeal_trust
# count    269.000000   269.000000      269.000000    269.000000      269.000000
# mean       0.843866     0.089219        0.531599      0.327138        0.275093
# std        0.363659     0.285591        0.499931      0.470042        0.447393
# min        0.000000     0.000000        0.000000      0.000000        0.000000
# 25%        1.000000     0.000000        0.000000      0.000000        0.000000
# 50%        1.000000     0.000000        1.000000      0.000000        0.000000
# 75%        1.000000     0.000000        1.000000      1.000000        1.000000
# max        1.000000     1.000000        1.000000      1.000000        1.000000

# %%
#assistance
modi_data.iloc[:,35:40].describe()
# Out:
#        amazon_assist  paytm_assist  flipkart_assist  myntra_assist  \
# count     269.000000    269.000000       269.000000     269.000000
# mean        0.851301      0.092937         0.505576       0.412639
# std         0.356455      0.290885         0.500901       0.493227
# min         0.000000      0.000000         0.000000       0.000000
# 25%         1.000000      0.000000         0.000000       0.000000
# 50%         1.000000      0.000000         1.000000       0.000000
# 75%         1.000000      0.000000         1.000000       1.000000
# max         1.000000      1.000000         1.000000       1.000000
#
#        snapdeal_assist
# count       269.000000
# mean          0.323420
# std           0.468653
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000

# %%
#how long the users logged in
modi_data.iloc[:,40:45].describe()
# Out:
#        amazon_long_log  paytm_long_log  flipkart_long_log  myntra_long_log  \
# count       269.000000      269.000000           269.0000       269.000000
# mean          0.501859        0.286245             0.3829         0.130112
# std           0.500929        0.452848             0.4870         0.337053
# min           0.000000        0.000000             0.0000         0.000000
# 25%           0.000000        0.000000             0.0000         0.000000
# 50%           1.000000        0.000000             0.0000         0.000000
# 75%           1.000000        1.000000             1.0000         0.000000
# max           1.000000        1.000000             1.0000         1.000000
#
#        snapdeal_long_log
# count         269.000000
# mean            0.249071
# std             0.433281
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000

# %%
#late declaration of price
modi_data.iloc[:,50:55].describe()
# Out:
#        amazon_late_price  paytm_late_price  flipkart_late_price  \
# count         269.000000        269.000000           269.000000
# mean            0.208178          0.267658             0.159851
# std             0.406762          0.443564             0.367151
# min             0.000000          0.000000             0.000000
# 25%             0.000000          0.000000             0.000000
# 50%             0.000000          0.000000             0.000000
# 75%             0.000000          1.000000             0.000000
# max             1.000000          1.000000             1.000000
#
#        myntra_late_price  snapdeal_late_price
# count          269.00000           269.000000
# mean             0.27881             0.178439
# std              0.44925             0.383595
# min              0.00000             0.000000
# 25%              0.00000             0.000000
# 50%              0.00000             0.000000
# 75%              1.00000             0.000000
# ...

# %%
#longer page loading time
modi_data.iloc[:,55:60].describe()
# Out:
#        amazon_long_load  paytm_long_load  flipkart_long_load  \
# count        269.000000       269.000000          269.000000
# mean           0.252788         0.349442            0.226766
# std            0.435421         0.477683            0.419520
# min            0.000000         0.000000            0.000000
# 25%            0.000000         0.000000            0.000000
# 50%            0.000000         0.000000            0.000000
# 75%            1.000000         1.000000            0.000000
# max            1.000000         1.000000            1.000000
#
#        myntra_long_load  snapdeal_long_load
# count        269.000000          269.000000
# mean           0.252788            0.234201
# std            0.435421            0.424288
# min            0.000000            0.000000
# 25%            0.000000            0.000000
# 50%            0.000000            0.000000
# 75%            1.000000            0.000000
# max            1.000000            1.000000

# %%
#limitd mode of payment
modi_data.iloc[:,60:65].describe()
# Out:
#        amazon_lim_pay_opt  paytm_lim_pay_opt  flipkart_lim_pay_opt  \
# count          269.000000         269.000000            269.000000
# mean             0.386617           0.197026              0.223048
# std              0.487882           0.398494              0.417066
# min              0.000000           0.000000              0.000000
# 25%              0.000000           0.000000              0.000000
# 50%              0.000000           0.000000              0.000000
# 75%              1.000000           0.000000              0.000000
# max              1.000000           1.000000              1.000000
#
#        myntra_lim_pay_opt  snapdeal_lim_pay_opt
# count          269.000000            269.000000
# mean             0.026022              0.405204
# std              0.159498              0.491847
# min              0.000000              0.000000
# 25%              0.000000              0.000000
# 50%              0.000000              0.000000
# ...

# %%
#longer delivery period
modi_data.iloc[:,65:70].describe()
# Out:
#        amazon_long_del_per  paytm_long_del_per  flipkart_long_del_per  \
# count           269.000000          269.000000             269.000000
# mean              0.137546            0.364312               0.163569
# std               0.345065            0.482134               0.370573
# min               0.000000            0.000000               0.000000
# 25%               0.000000            0.000000               0.000000
# 50%               0.000000            0.000000               0.000000
# 75%               0.000000            1.000000               0.000000
# max               1.000000            1.000000               1.000000
#
#        myntra_long_del_per  snapdeal_long_del_per
# count           269.000000             269.000000
# mean              0.096654               0.334572
# std               0.296037               0.472720
# min               0.000000               0.000000
# 25%               0.000000               0.000000
# ...

# %%
#how long the users logged in
modi_data.iloc[:,70:75].describe()
# Out:
#        amazon_change_site  paytm_change_site  flipkart_change_site  \
# count          269.000000         269.000000            269.000000
# mean             0.524164           0.234201              0.267658
# std              0.500347           0.424288              0.443564
# min              0.000000           0.000000              0.000000
# 25%              0.000000           0.000000              0.000000
# 50%              1.000000           0.000000              0.000000
# 75%              1.000000           0.000000              1.000000
# max              1.000000           1.000000              1.000000
#
#        myntra_change_site  snapdeal_change_site
# count          269.000000            269.000000
# mean             0.137546              0.029740
# std              0.345065              0.170185
# min              0.000000              0.000000
# 25%              0.000000              0.000000
# 50%              0.000000              0.000000
# ...

# %%
#frequent disruption
modi_data.iloc[:,75:80].describe()
# Out:
#        amazon_freq_dis  paytm_freq_dis  flipkart_freq_dis  myntra_freq_dis  \
# count       269.000000      269.000000         269.000000       269.000000
# mean          0.289963        0.144981           0.230483         0.245353
# std           0.454591        0.352738           0.421927         0.431098
# min           0.000000        0.000000           0.000000         0.000000
# 25%           0.000000        0.000000           0.000000         0.000000
# 50%           0.000000        0.000000           0.000000         0.000000
# 75%           1.000000        0.000000           0.000000         0.000000
# max           1.000000        1.000000           1.000000         1.000000
#
#        snapdeal_freq_dis
# count         269.000000
# mean            0.275093
# std             0.447393
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             1.000000
# max             1.000000

# %%
#is efficient as before
modi_data.iloc[:,80:85].describe()
# Out:
#        amazon_efficient  paytm_efficient  flipkart_efficient  \
# count        269.000000       269.000000          269.000000
# mean           0.676580         0.215613            0.434944
# std            0.468653         0.412014            0.496674
# min            0.000000         0.000000            0.000000
# 25%            0.000000         0.000000            0.000000
# 50%            1.000000         0.000000            0.000000
# 75%            1.000000         0.000000            1.000000
# max            1.000000         1.000000            1.000000
#
#        myntra_efficient  snapdeal_efficient
# count        269.000000          269.000000
# mean           0.052045            0.092937
# std            0.222531            0.290885
# min            0.000000            0.000000
# 25%            0.000000            0.000000
# 50%            0.000000            0.000000
# 75%            0.000000            0.000000
# max            1.000000            1.000000

# %%
#recommend
modi_data.iloc[:,85:90].describe()
# Out:
#        amazon_reccommend  paytm_reccommend  flipkart_reccommend  \
# count         269.000000        269.000000           269.000000
# mean            0.814126          0.163569             0.472119
# std             0.389730          0.370573             0.500153
# min             0.000000          0.000000             0.000000
# 25%             1.000000          0.000000             0.000000
# 50%             1.000000          0.000000             0.000000
# 75%             1.000000          0.000000             1.000000
# max             1.000000          1.000000             1.000000
#
#        myntra_reccommend  snapdeal_reccommend
# count         269.000000           269.000000
# mean            0.282528             0.040892
# std             0.451068             0.198410
# min             0.000000             0.000000
# 25%             0.000000             0.000000
# 50%             0.000000             0.000000
# 75%             1.000000             0.000000
# ...

# %% [raw]
# by using above customer data, we can say that Amazon scores the highest score in terms of website quality and service related to the products
# Second best score is for Flipkart
# More than 80% of the people recommend amazon to their friends or family
